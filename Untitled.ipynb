# %%
from models.mobilenetv3.mobilenetv3_small import MobileNetV3Small

# %%
model = MobileNetV3Small(num_classes=2, pretrained=True, features_fixed=True)

# %%
model.state_dict()
# Out:
# OrderedDict([('features.0.0.weight',
#               tensor([[[[ 8.8910e-01,  1.1631e+00,  1.0091e+00],
#                         [ 9.5930e-01,  1.2193e+00,  9.6384e-01],
#                         [ 6.5313e-02,  1.5293e-01,  1.4711e-02]],
#
#                        [[-7.8151e-01, -9.7928e-01, -8.6442e-01],
#                         [-8.0640e-01, -1.0021e+00, -7.8933e-01],
#                         [-5.6666e-02, -1.2355e-01, -3.5512e-02]],
#
#                        [[-5.1425e-02, -7.3042e-02, -7.5605e-02],
#                         [-6.2844e-02, -8.1305e-02, -7.0897e-02],
#                         [-1.3165e-02, -1.2108e-02,  9.3963e-03]]],
#
#
#                       [[[-2.5147e-02, -1.2394e-02, -3.1039e-03],
#                         [ 3.8673e-01,  7.3674e-01,  4.2038e-01],
#                         [-3.7819e-01, -7.0812e-01, -3.9542e-01]],
#
#                        [[ 1.4524e-02,  1.7363e-02,  4.0762e-03],
#                         [ 8.0259e-01,  1.6647e+00,  9.0791e-01],
# ...

# %%
from torch.optim import SGD

# %%
optimizer = SGD(params=model.parameters(), lr=1e-3)
